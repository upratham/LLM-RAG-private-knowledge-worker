# %%
import sys
from pathlib import Path

PROJECT_ROOT =Path(Path.cwd()).parent  # adjust if notebook isn't at repo root
# If your notebook is in e.g. notebooks/, use: Path.cwd().parent

sys.path.insert(0, str(PROJECT_ROOT))

# %% [markdown]
# ### Set up the 2 key LangChain objects: retriever and llm

# %%
from src.retriever import get_retriever
db_path=Path(str(PROJECT_ROOT)) / "vectors"
retriever=get_retriever(db_path=db_path)
retriever.invoke("who is Mamoon Rashid ?")
# Out:
# [Document(id='90e7fa82-6e26-4b53-adc8-8fcf2e9937ff', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\An_Efficient_Deep_Learning_based_Approach_for_the_Detection_of_Brain_Tumors.md', 'type': 'research_papers'}, page_content='202000611@vupune.ac.in 202001143@vupune.ac.in 202001369@vupune.ac.in\nJanvi Anand Pagariya Mamoon Rashid\nResearch Center of Excellence for Research Center of Excellence for\nHealth Informatics Health Informatics\nVishwakarma University Vishwakarma University\nPune, India. Pune, India.\n202001239@vupune.ac.in mamoon.rashid@vupune.ac.in\nAbstract— Deep learning has stretched out its roots even neurologists to treat is appallingly small, which is our\nmore in our daily lives. As a society, we are witnessing small devastating reality [4].\nchanges in lifestyle such as self-driving cars, Google Assistant,\nThe typical technique used by neurologists to identify'),
#  Document(id='daaeb115-466a-462d-96e6-59a300c28c9b', metadata={'type': 'research_papers', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Fall_Detection_Methods_for_Elderly_People-_A_Comprehensive_Survey.md'}, page_content='Abhiraj Sandeep Gadade Mamoon Rashid\nResearch Center of Excellence Research Center of Excellence\nfor Health Informatics for Health Informatics\nVishwakarma University Vishwakarma University\nPune, India. Pune, India.\n202001236@vupune.ac.in mamoon.rashid@vupune.ac.in\nAbstract— This survey research gives a thorough analysis physical injuries like fractures and head trauma, as well as\nof sensor technology and picture preprocessing methods for fall psychological effects like fear of falling again and a decline\ndetection systems for elderly people. Caretakers face serious in overall mobility. As the average age of the falling elderly\nhealth hazards and difficulties when an older person falls.'),
#  Document(id='aa54433e-4fd4-4ac0-b647-db29f698997c', metadata={'type': 'research_papers', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Efficient Segmentation Approach for The Traceability of Breast Cancer Tissues to Improve Diagnostic Accuracy in Ultrasound Images.md'}, page_content='Maryland 20742, USA\n2 Ira A. Fulton Schools of Engineering, Arizona State University, Arizona 85281, United States\n3 Department of AI and Engineering, Wednesday Solutions, Pune 411013, India\n4 School of Information Communication and Technology, Bahrain Polytechnic, Isa Town 33349, Bahrain\n5 Department of Information Systems, College of Computer and Information Science, Princess Nourah bint Abdulrahman\nUniversity, Riyadh 11671, Saudi Arabia\n6 Department of Computer Science, College of Computer Science, King Khalid University, Abha 61421, Saudi Arabia\nCorresponding Author Email: mamoon873@gmail.com'),
#  Document(id='647ddc3e-38c7-4c6c-9fc5-e6610a8d5af3', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Efficient Segmentation Approach for The Traceability of Breast Cancer Tissues to Improve Diagnostic Accuracy in Ultrasound Images.md', 'type': 'research_papers'}, page_content='University, Riyadh 11671, Saudi Arabia\n6 Department of Computer Science, College of Computer Science, King Khalid University, Abha 61421, Saudi Arabia\nCorresponding Author Email: mamoon873@gmail.com\nCopyright: ©2025 The authors. This article is published by IIETA and is licensed under the CC BY 4.0 license\n(http://creativecommons.org/licenses/by/4.0/).\nhttps://doi.org/10.18280/ts.420540 ABSTRACT\nReceived: 19 August 2025 Breast cancer continues to be a leading concern in global health, reaching across diverse\nRevised: 26 August 2025 populations, and requires correct detection through early intervention. This is especially the'),
#  Document(id='2199c3e0-0788-4a0c-9630-57c14c863246', metadata={'type': 'research_papers', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Role of big data analytics in healthcare systems _ Medical Imaging Informatics.md'}, page_content='Authors: Prathamesh Suhas Uravane, Vedant Vinay Ganthade, Adityaraj Sanjay Belhe, Abhiraj Sandeep\nGadade, and Mamoon Rashid Authors Info & Affiliations\nPublication: Medical Imaging Informatics: Machine learning, deep learning and big data analytics\nhttps://doi.org/10.1049/PBHE057E_ch13\nꄀ 🔔 ” 🔓 Get access\n📌 🛈 📈 🔓 🔗 \ue410 \ue93d \uef1b 🗫\nAbstract\nGenerating data at an abundant scale has become a boon nowadays, as we see the shining side of\nits features and practicality but, data quality, integrating it with other physical, cloud systems, or\nstoring this data could be impenetrable. Every sector including finance, retail, government, and'),
#  Document(id='13eb80d1-6b2a-44bc-a5da-40f876c59342', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Role of big data analytics in healthcare systems _ Medical Imaging Informatics.md', 'type': 'research_papers'}, page_content='data analytics. In 2017 International Conference on Innovations in Information, Embedded and\nCommunication Systems (ICIIECS) (pp. 1–4). IEEE.\nGoogle Scholar\n27. Jan, B., Farman, H., Khan, M., et al. (2019). Deep learning in big data analytics: a comparative study.\nComputers & Electrical Engineering, 75, 275–287.\nGoogle Scholar\n28. Rashid, M., Yousuf, M. M., Ram, B., and Goyal, V. (2019). Novel big data approach for drug prediction in\nhealth care systems. In 2019 International conference on automation, computational and technology\nmanagement (ICACTM) (pp. 325–329). IEEE.\nGoogle Scholar'),
#  Document(id='c52a04f5-b552-4c5f-a0f2-e2e26c07b491', metadata={'type': 'repo_summaries', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\LLM-Debate-Competition.md'}, page_content='---\n\n## Author\nMaintained by **Prathamesh Uravane**  \nEmail: [upratham2002@gmail.com](mailto:upratham2002@gmail.com)\n\n---\n\n*Note: Some details, such as the exact implementation of the debate flow or scoring schema, are inferred from the provided files and descriptions. For precise behavior, review the `Debate_Competittion.ipynb` directly.*'),
#  Document(id='2a689133-7aef-41a0-a13d-6e1ad27b2912', metadata={'type': 'research_papers', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\An_Efficient_Deep_Learning_based_Approach_for_the_Detection_of_Brain_Tumors.md'}, page_content='using deep neural network and machine learning algorithm." In 2019\n9th international conference on computer and knowledge engineering\n(ICCKE), pp. 363-368. IEEE, 2019.\n[4] Kumar, Abhishek, Jyoti Rawat, Indrajeet Kumar, Mamoon Rashid,\nKamred Udham Singh, Yasser D. Al‐Otaibi, and Usman Tariq.\n"Computer ‐ aided deep learning model for identification of\nlymphoblast cell using microscopic leukocyte images." Expert\nSystems, vol. 39, no. 4, e12894, 2022.\n[5] Sajid, Sidra, Saddam Hussain, and Amna Sarwar. "Brain tumor\ndetection and segmentation in MR images using deep learning."\nArabian Journal for Science and Engineering, vol. 44, no. 11, pp. 9249-\n9261, 2019.'),
#  Document(id='2873ea1d-c01e-4568-b21f-3b25818004fe', metadata={'type': 'research_papers', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Efficient Segmentation Approach for The Traceability of Breast Cancer Tissues to Improve Diagnostic Accuracy in Ultrasound Images.md'}, page_content='Abdulrahman University Researchers Supporting Project [14] Abo-El-Rejal, A., Ayman, S., Aymen, F. (2024).\nnumber (PNURSP2025R195), Princess Nourah bint Advances in breast cancer segmentation: A\nAbdulrahman University, Riyadh, Saudi Arabia. comprehensive review. Acadlore Transactions on AI and\nMachine Learning, 3(2): 70-83.\nhttps://doi.org/10.56578/ataiml030201\nREFERENCES [15] Podda, A.S., Balia, R., Barra, S., Carta, S., Fenu, G.,\nPiano, L. (2022). Fully-automated deep learning pipeline\n[1] World Health Organization. Breast cancer. for segmentation and classification of breast ultrasound\nhttps://www.who.int/news-room/fact- images. Journal of Computational Science, 63: 101816.'),
#  Document(id='fd703c6b-b89a-4086-8060-09b0df325022', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\An_Efficient_Deep_Learning_based_Approach_for_the_Detection_of_Brain_Tumors.md', 'type': 'research_papers'}, page_content='detection and segmentation in MR images using deep learning."\nArabian Journal for Science and Engineering, vol. 44, no. 11, pp. 9249-\n9261, 2019.\n[6] Saba, Tanzila, Ahmed Sameh Mohamed, Mohammad El-Affendi,\nJaveria Amin, and Muhammad Sharif. "Brain tumor detection using\nfusion of hand crafted and deep learning features." Cognitive Systems\nResearch, vol. 59, pp. 221-230, 2020.\n[7] Kumar, Indrajeet, Sultan S. Alshamrani, Abhishek Kumar, Jyoti\nRawat, Kamred Udham Singh, Mamoon Rashid, and Ahmed Saeed\nAlGhamdi. "Deep learning approach for analysis and characterization\nof COVID-19." Computers, Materials and Continua, pp. 451-468,\n2021.')]

# %% [markdown]
# ### Advanced RAG Rerank the chunks

# %%
from pydantic import BaseModel,Field

class RankOrder(BaseModel):
   order: list[int] = Field(description="he order of relevance of chunks, from most relevant to least relevant, by chunk id number")

# %%
from openai import OpenAI
ollama_host = "http://localhost:11434"  # Adjust if your Ollama server is running on a different URL or port
ollama_base_url = f"{ollama_host}/v1"
ollama_model="llama3.2"
ollama_client = OpenAI(base_url=ollama_base_url, api_key="ollama")

# %%
from src.rag_system import rewrite_query,fetch_unranked_chunks,merge_chunks,rerank
# Out:
# d:\LLM\Projects\LLM-RAG-private-knowldge-worker\src\rag_system.py:26: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3.2", base_url=ollama_host, temperature=0)

# %%
question="who is Mamoon Rashid ?"
unranked_chunks=fetch_unranked_chunks(question, retriever)
unranked_chunks
# Out:
# [Document(id='90e7fa82-6e26-4b53-adc8-8fcf2e9937ff', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\An_Efficient_Deep_Learning_based_Approach_for_the_Detection_of_Brain_Tumors.md', 'type': 'research_papers'}, page_content='202000611@vupune.ac.in 202001143@vupune.ac.in 202001369@vupune.ac.in\nJanvi Anand Pagariya Mamoon Rashid\nResearch Center of Excellence for Research Center of Excellence for\nHealth Informatics Health Informatics\nVishwakarma University Vishwakarma University\nPune, India. Pune, India.\n202001239@vupune.ac.in mamoon.rashid@vupune.ac.in\nAbstract— Deep learning has stretched out its roots even neurologists to treat is appallingly small, which is our\nmore in our daily lives. As a society, we are witnessing small devastating reality [4].\nchanges in lifestyle such as self-driving cars, Google Assistant,\nThe typical technique used by neurologists to identify'),
#  Document(id='daaeb115-466a-462d-96e6-59a300c28c9b', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Fall_Detection_Methods_for_Elderly_People-_A_Comprehensive_Survey.md', 'type': 'research_papers'}, page_content='Abhiraj Sandeep Gadade Mamoon Rashid\nResearch Center of Excellence Research Center of Excellence\nfor Health Informatics for Health Informatics\nVishwakarma University Vishwakarma University\nPune, India. Pune, India.\n202001236@vupune.ac.in mamoon.rashid@vupune.ac.in\nAbstract— This survey research gives a thorough analysis physical injuries like fractures and head trauma, as well as\nof sensor technology and picture preprocessing methods for fall psychological effects like fear of falling again and a decline\ndetection systems for elderly people. Caretakers face serious in overall mobility. As the average age of the falling elderly\nhealth hazards and difficulties when an older person falls.'),
#  Document(id='aa54433e-4fd4-4ac0-b647-db29f698997c', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Efficient Segmentation Approach for The Traceability of Breast Cancer Tissues to Improve Diagnostic Accuracy in Ultrasound Images.md', 'type': 'research_papers'}, page_content='Maryland 20742, USA\n2 Ira A. Fulton Schools of Engineering, Arizona State University, Arizona 85281, United States\n3 Department of AI and Engineering, Wednesday Solutions, Pune 411013, India\n4 School of Information Communication and Technology, Bahrain Polytechnic, Isa Town 33349, Bahrain\n5 Department of Information Systems, College of Computer and Information Science, Princess Nourah bint Abdulrahman\nUniversity, Riyadh 11671, Saudi Arabia\n6 Department of Computer Science, College of Computer Science, King Khalid University, Abha 61421, Saudi Arabia\nCorresponding Author Email: mamoon873@gmail.com'),
#  Document(id='647ddc3e-38c7-4c6c-9fc5-e6610a8d5af3', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Efficient Segmentation Approach for The Traceability of Breast Cancer Tissues to Improve Diagnostic Accuracy in Ultrasound Images.md', 'type': 'research_papers'}, page_content='University, Riyadh 11671, Saudi Arabia\n6 Department of Computer Science, College of Computer Science, King Khalid University, Abha 61421, Saudi Arabia\nCorresponding Author Email: mamoon873@gmail.com\nCopyright: ©2025 The authors. This article is published by IIETA and is licensed under the CC BY 4.0 license\n(http://creativecommons.org/licenses/by/4.0/).\nhttps://doi.org/10.18280/ts.420540 ABSTRACT\nReceived: 19 August 2025 Breast cancer continues to be a leading concern in global health, reaching across diverse\nRevised: 26 August 2025 populations, and requires correct detection through early intervention. This is especially the'),
#  Document(id='2199c3e0-0788-4a0c-9630-57c14c863246', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Role of big data analytics in healthcare systems _ Medical Imaging Informatics.md', 'type': 'research_papers'}, page_content='Authors: Prathamesh Suhas Uravane, Vedant Vinay Ganthade, Adityaraj Sanjay Belhe, Abhiraj Sandeep\nGadade, and Mamoon Rashid Authors Info & Affiliations\nPublication: Medical Imaging Informatics: Machine learning, deep learning and big data analytics\nhttps://doi.org/10.1049/PBHE057E_ch13\nꄀ 🔔 ” 🔓 Get access\n📌 🛈 📈 🔓 🔗 \ue410 \ue93d \uef1b 🗫\nAbstract\nGenerating data at an abundant scale has become a boon nowadays, as we see the shining side of\nits features and practicality but, data quality, integrating it with other physical, cloud systems, or\nstoring this data could be impenetrable. Every sector including finance, retail, government, and'),
#  Document(id='13eb80d1-6b2a-44bc-a5da-40f876c59342', metadata={'type': 'research_papers', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Role of big data analytics in healthcare systems _ Medical Imaging Informatics.md'}, page_content='data analytics. In 2017 International Conference on Innovations in Information, Embedded and\nCommunication Systems (ICIIECS) (pp. 1–4). IEEE.\nGoogle Scholar\n27. Jan, B., Farman, H., Khan, M., et al. (2019). Deep learning in big data analytics: a comparative study.\nComputers & Electrical Engineering, 75, 275–287.\nGoogle Scholar\n28. Rashid, M., Yousuf, M. M., Ram, B., and Goyal, V. (2019). Novel big data approach for drug prediction in\nhealth care systems. In 2019 International conference on automation, computational and technology\nmanagement (ICACTM) (pp. 325–329). IEEE.\nGoogle Scholar'),
#  Document(id='c52a04f5-b552-4c5f-a0f2-e2e26c07b491', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\LLM-Debate-Competition.md', 'type': 'repo_summaries'}, page_content='---\n\n## Author\nMaintained by **Prathamesh Uravane**  \nEmail: [upratham2002@gmail.com](mailto:upratham2002@gmail.com)\n\n---\n\n*Note: Some details, such as the exact implementation of the debate flow or scoring schema, are inferred from the provided files and descriptions. For precise behavior, review the `Debate_Competittion.ipynb` directly.*'),
#  Document(id='2a689133-7aef-41a0-a13d-6e1ad27b2912', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\An_Efficient_Deep_Learning_based_Approach_for_the_Detection_of_Brain_Tumors.md', 'type': 'research_papers'}, page_content='using deep neural network and machine learning algorithm." In 2019\n9th international conference on computer and knowledge engineering\n(ICCKE), pp. 363-368. IEEE, 2019.\n[4] Kumar, Abhishek, Jyoti Rawat, Indrajeet Kumar, Mamoon Rashid,\nKamred Udham Singh, Yasser D. Al‐Otaibi, and Usman Tariq.\n"Computer ‐ aided deep learning model for identification of\nlymphoblast cell using microscopic leukocyte images." Expert\nSystems, vol. 39, no. 4, e12894, 2022.\n[5] Sajid, Sidra, Saddam Hussain, and Amna Sarwar. "Brain tumor\ndetection and segmentation in MR images using deep learning."\nArabian Journal for Science and Engineering, vol. 44, no. 11, pp. 9249-\n9261, 2019.'),
#  Document(id='2873ea1d-c01e-4568-b21f-3b25818004fe', metadata={'type': 'research_papers', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\Efficient Segmentation Approach for The Traceability of Breast Cancer Tissues to Improve Diagnostic Accuracy in Ultrasound Images.md'}, page_content='Abdulrahman University Researchers Supporting Project [14] Abo-El-Rejal, A., Ayman, S., Aymen, F. (2024).\nnumber (PNURSP2025R195), Princess Nourah bint Advances in breast cancer segmentation: A\nAbdulrahman University, Riyadh, Saudi Arabia. comprehensive review. Acadlore Transactions on AI and\nMachine Learning, 3(2): 70-83.\nhttps://doi.org/10.56578/ataiml030201\nREFERENCES [15] Podda, A.S., Balia, R., Barra, S., Carta, S., Fenu, G.,\nPiano, L. (2022). Fully-automated deep learning pipeline\n[1] World Health Organization. Breast cancer. for segmentation and classification of breast ultrasound\nhttps://www.who.int/news-room/fact- images. Journal of Computational Science, 63: 101816.'),
#  Document(id='fd703c6b-b89a-4086-8060-09b0df325022', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\research_papers\\An_Efficient_Deep_Learning_based_Approach_for_the_Detection_of_Brain_Tumors.md', 'type': 'research_papers'}, page_content='detection and segmentation in MR images using deep learning."\nArabian Journal for Science and Engineering, vol. 44, no. 11, pp. 9249-\n9261, 2019.\n[6] Saba, Tanzila, Ahmed Sameh Mohamed, Mohammad El-Affendi,\nJaveria Amin, and Muhammad Sharif. "Brain tumor detection using\nfusion of hand crafted and deep learning features." Cognitive Systems\nResearch, vol. 59, pp. 221-230, 2020.\n[7] Kumar, Indrajeet, Sultan S. Alshamrani, Abhishek Kumar, Jyoti\nRawat, Kamred Udham Singh, Mamoon Rashid, and Ahmed Saeed\nAlGhamdi. "Deep learning approach for analysis and characterization\nof COVID-19." Computers, Materials and Continua, pp. 451-468,\n2021.')]

# %%
question = "Who is the director of UMA?"
chunks = fetch_unranked_chunks(question, retriever)

# %%
reranked = rerank(question, chunks)
reranked
# Out:
# input chunks:, [Document(id='8fcf903b-5b57-4e26-b4a6-69c3f0abaa4e', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA-V-2.md', 'type': 'repo_summaries'}, page_content='<!-- Generated: 2026-02-15T03:03:41.012793Z | Model: gpt-4.1-nano -->\n\n# UMA-V-2 Repository Documentation\n\n## Overview\nThe **UMA-V-2** repository appears to be a comprehensive collection of web-based educational resources focused on anatomy, biology, and chemistry practicals. It includes static web pages, 3D models, multimedia content, and backend PHP scripts for user management and data handling. The repository is intended for students and educators to access interactive lab simulations, practical instructions, and assessment tools within a virtual laboratory environment.\n\n---'), Document(id='a7e4a20e-dd1e-4333-8167-440ad5b8faed', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\internships\\uma-internship-completion.md', 'type': 'internships'}, page_content='# UMA – Internship / Project Completion Certificate (2024)\n\n## Certificate Type\n**Certificate of Completion**\n\n## Issued By\n**Universidad María Auxiliadora (UMA)**\n\n## Recipient\n**Prathamesh Uravane**\n\n## Project Title\n**Virtual Tutor for Comprehensive Student Monitoring**\n\n## Duration\n**8 March 2024 – 7 July 2024**\n\n## Description\nThis certificate confirms successful completion of the project focused on building a **virtual tutor** to support comprehensive student monitoring. The project mentions evaluating student **attendance, performance, and attentiveness**, including use of **facial recognition** and automation of report generation for academic staff.'), Document(id='30c6eca4-8e8f-49e7-97a9-2a7a8305aeaa', metadata={'type': 'repo_summaries', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA_dropout_prediction_for_students.md'}, page_content='<!-- Generated: 2026-02-15T03:00:56.003390Z | Model: gpt-4.1-nano -->\n\n# UMA_dropout_prediction_for_students\n\n## Overview\nThis repository provides a machine learning-based system to predict whether a student is likely to drop out. It is designed for educational institutions, data scientists, and developers interested in student retention analytics. The system leverages multiple models and offers both a Jupyter Notebook interface and a Flask API for deployment and integration.'), Document(id='41e80d1d-eaa2-4114-8ab4-203e61e63d19', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA-V-2.md', 'type': 'repo_summaries'}, page_content='---\n\n## Setup & Run\nBased on the provided files:\n\n1. **Database Setup:**\n   - Import `stud_name.sql` and `users.sql` into your MySQL server.\n   - Ensure the database `virtual_lab_sim` exists and the tables are created with the sample data.\n\n2. **Server Environment:**\n   - The PHP scripts require a web server with PHP support (e.g., Apache or Nginx with PHP).\n   - The `Dockerfile` indicates a PHP 8.1 environment with Apache and MySQL extensions. To run via Docker:\n     ```bash\n     docker build -t uma-v2 .\n     docker run -d -p 8080:80 uma-v2\n     ```\n   - Alternatively, set up a local PHP server and point it to the repository directory.'), Document(id='a01f9b01-1ba7-401f-a6aa-fe0d20736ea3', metadata={'type': 'transcripts', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Transcripts\\Testudo - Unofficial Transcript.md'}, page_content='MSML606 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML604 PCS3 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML604 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML604 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML606 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML605 PCS1 3.00 REG D 10/30/25 12/04/25 12/04/25\nMSML604 PCS3 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML605 PCS1 3.00 REG D 10/30/25 10/30/25 10/30/25\nht ...
# parsed response from reranker: order=[2, 1, 8, 4, 3, 9, 10, 6, 5, 7]
# reranked order of chunk ids: [2, 1, 8, 4, 3, 9, 10, 6, 5, 7]
# [Document(id='a7e4a20e-dd1e-4333-8167-440ad5b8faed', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\internships\\uma-internship-completion.md', 'type': 'internships'}, page_content='# UMA – Internship / Project Completion Certificate (2024)\n\n## Certificate Type\n**Certificate of Completion**\n\n## Issued By\n**Universidad María Auxiliadora (UMA)**\n\n## Recipient\n**Prathamesh Uravane**\n\n## Project Title\n**Virtual Tutor for Comprehensive Student Monitoring**\n\n## Duration\n**8 March 2024 – 7 July 2024**\n\n## Description\nThis certificate confirms successful completion of the project focused on building a **virtual tutor** to support comprehensive student monitoring. The project mentions evaluating student **attendance, performance, and attentiveness**, including use of **facial recognition** and automation of report generation for academic staff.'),
#  Document(id='8fcf903b-5b57-4e26-b4a6-69c3f0abaa4e', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA-V-2.md', 'type': 'repo_summaries'}, page_content='<!-- Generated: 2026-02-15T03:03:41.012793Z | Model: gpt-4.1-nano -->\n\n# UMA-V-2 Repository Documentation\n\n## Overview\nThe **UMA-V-2** repository appears to be a comprehensive collection of web-based educational resources focused on anatomy, biology, and chemistry practicals. It includes static web pages, 3D models, multimedia content, and backend PHP scripts for user management and data handling. The repository is intended for students and educators to access interactive lab simulations, practical instructions, and assessment tools within a virtual laboratory environment.\n\n---'),
#  Document(id='0becdd8b-cac7-4800-825e-6793809377f7', metadata={'type': 'repo_summaries', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA-V-2.md'}, page_content='- **Frontend:** HTML pages styled with embedded CSS, providing navigation, user profile sections, and links to practical modules.\n- **Backend:** PHP scripts (`register.php`, `logout.php`, `header.php`, `homepage_d.php`, `add_student.php`, `insert_marks.php`) handle user sessions, registration, data insertion, and updates.\n- **Database:** MySQL with tables for users (`users`), student marks (`stud_name`), and student details (`stud_name`).\n- **Resources:** Organized into folders such as `Anatomy_pract_templets`, `Biology_Prac_Templates`, and `Chemistry_Prac_Templates`, containing models, images, videos, and HTML/PHP pages.'),
#  Document(id='41e80d1d-eaa2-4114-8ab4-203e61e63d19', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA-V-2.md', 'type': 'repo_summaries'}, page_content='---\n\n## Setup & Run\nBased on the provided files:\n\n1. **Database Setup:**\n   - Import `stud_name.sql` and `users.sql` into your MySQL server.\n   - Ensure the database `virtual_lab_sim` exists and the tables are created with the sample data.\n\n2. **Server Environment:**\n   - The PHP scripts require a web server with PHP support (e.g., Apache or Nginx with PHP).\n   - The `Dockerfile` indicates a PHP 8.1 environment with Apache and MySQL extensions. To run via Docker:\n     ```bash\n     docker build -t uma-v2 .\n     docker run -d -p 8080:80 uma-v2\n     ```\n   - Alternatively, set up a local PHP server and point it to the repository directory.'),
#  Document(id='30c6eca4-8e8f-49e7-97a9-2a7a8305aeaa', metadata={'type': 'repo_summaries', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA_dropout_prediction_for_students.md'}, page_content='<!-- Generated: 2026-02-15T03:00:56.003390Z | Model: gpt-4.1-nano -->\n\n# UMA_dropout_prediction_for_students\n\n## Overview\nThis repository provides a machine learning-based system to predict whether a student is likely to drop out. It is designed for educational institutions, data scientists, and developers interested in student retention analytics. The system leverages multiple models and offers both a Jupyter Notebook interface and a Flask API for deployment and integration.'),
#  Document(id='d84a67e9-f9b0-4bc4-9c5b-a87a428e2255', metadata={'type': 'resume', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\5 Resume- Uravane Prathamesh Suhas.md'}, page_content='(UMA,Lima, Technologies: Python / FastAPI / Gradio / Machine Learning / MySQL / Data Preprocessing /\nPeru) Feature Engineering / Joblib / Pandas / Scikit-Learn\n4. Advanced Preprocessing Pipeline for Breast Cancer Segmentation.\nFor the segmentation of breast cancer CT scan images using multiple segmentation models, an\nadvanced preprocessing pipeline implemented. Used dataset has taken from open-source\nMarch 24 platform Kaggle. The preprocessing pipeline improves images using various pre-processing\n- techniques which consequently allows model to perform well. The models are trained to segment'),
#  Document(id='c52a04f5-b552-4c5f-a0f2-e2e26c07b491', metadata={'type': 'repo_summaries', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\LLM-Debate-Competition.md'}, page_content='---\n\n## Author\nMaintained by **Prathamesh Uravane**  \nEmail: [upratham2002@gmail.com](mailto:upratham2002@gmail.com)\n\n---\n\n*Note: Some details, such as the exact implementation of the debate flow or scoring schema, are inferred from the provided files and descriptions. For precise behavior, review the `Debate_Competittion.ipynb` directly.*'),
#  Document(id='4669674a-d3c6-4118-824b-1903e8a136b2', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\AI_ML Resume 5 Prathamesh Uravane.md', 'type': 'resume'}, page_content='Prathamesh Uravane\nWashington DC, Baltimore Area | +1 (732) 318-9234 | upratham2002@gmail.com\nlinkedin.com/in/upratham/ | https://github.com/upratham|Google Scholar Profile\nEDUCATION\nUniversity of Maryland, College Park Expected: May 2027\nMaster of Science in Applied Machine Learning ; GPA: 4.0/ 4.0 College Park, Maryland\nVishwakarma University May 2024\nB.Tech in Artificial Intelligence and Data Science ; GPA: 3.75 / 4 Pune, India\n● Featured in Times of India for Developing real time fall detection system\n● AI/ML Core Team Member, Google Developer Student Club\nTECHNICAL SKILLS\nMachine Learning: Sci-kit Learn, Keras, Tensorflow, PyTorch.HuggingFace,LLMs'),
#  Document(id='a01f9b01-1ba7-401f-a6aa-fe0d20736ea3', metadata={'type': 'transcripts', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Transcripts\\Testudo - Unofficial Transcript.md'}, page_content='MSML606 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML604 PCS3 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML604 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML604 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML606 PCS2 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML605 PCS1 3.00 REG D 10/30/25 12/04/25 12/04/25\nMSML604 PCS3 3.00 REG D 10/30/25 10/30/25 10/30/25\nMSML605 PCS1 3.00 REG D 10/30/25 10/30/25 10/30/25\nhttps://app.testudo.umd.edu/#/main/uotrans?null 1/2'),
#  Document(id='1d2f649d-951e-4fd6-a703-1f73971d9afd', metadata={'type': 'resume', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\Resume 6 Prathamesh Uravane.md'}, page_content='Prathamesh Uravane\nWashington DC, Baltimore Area | +1 (732) 318-9234 | upratham2002@gmail.com\nlinkedin.com/in/upratham/ | https://github.com/upratham|Google Scholar Profile\nEDUCATION\nUniversity of Maryland, College Park Anticipated Graduation: May 2027\nMaster of Science in Applied Machine Learning; GPA: 4.0/ 4.0 College Park, Maryland\nVishwakarma University May 2024\nB.Tech in Artificial Intelligence and Data Science ; GPA: 3.75 / 4 Pune, India\n● Featured in Times of India for Developing real time fall detection system\n● AI/ML Core Team Member, Google Developer Student Club\nTECHNICAL SKILLS\nMachine Learning: Sci-kit Learn, Keras, Tensorflow, PyTorch.HuggingFace,LLMs')]

# %% [markdown]
# ### make rag message

# %%
SYSTEM_PROMPT_TEMPLATE = """
You are a helpful, knowledgeable assistant with access to a user's personal knowledge base.
Your role is to answer questions about the user's background, experience, achievements, and projects based on provided context.

while answering questions:
- Dont refere any document.
- understand the nuance of the question and depend on that provide short or long detailed answer.
- Maintain a polite and friendly tone
- If information is not available in the provided context, clearly state that you don't have that information
- don't mention name of any document use it for your context only.
- While answering strictly do not mentionany reference also , like "as per document 1, document 2, according to knowledge base" etc.

Context:
{context}
"""

# %%
def _history_to_messages(history):
    msgs = []
    for pair in history or []:
        # pair can be tuple/list like (user, assistant) or [user, assistant]
        if not pair or len(pair) != 2:
            continue
        user_msg, assistant_msg = pair

        if user_msg:
            msgs.append({"role": "user", "content": str(user_msg)})
        if assistant_msg:
            msgs.append({"role": "assistant", "content": str(assistant_msg)})

    return msgs

def make_rag_messages(question, history, chunks):
    context = "\n\n".join(
        f"Extract from {chunk.metadata.get('source','unknown')}:\n{chunk.page_content}"
        for chunk in chunks
    )
    system_prompt = SYSTEM_PROMPT_TEMPLATE.format(context=context)

    return (
        [{"role": "system", "content": system_prompt}]
        + _history_to_messages(history)
        + [{"role": "user", "content": question}]
    )

# %%
que="where did Prathamesh completed SSC?"

query=rewrite_query(que, [])
query
# Out:
# '"Prathamesh education SSC location"'

# %%
def fetch_context(original_question,retriever,top_k=8):
    rewritten_question = rewrite_query(original_question)
    chunks1 = fetch_unranked_chunks(original_question, retriever)
    chunks2 = fetch_unranked_chunks(rewritten_question, retriever)
    chunks = merge_chunks(chunks1, chunks2)
    reranked = rerank(original_question, chunks)
    return reranked[:top_k]

# %%
from tenacity import retry, wait_exponential
# wait = wait_exponential(multiplier=1, min=10, max=240)
# @retry(wait=wait)
def answer_question(question: str, history: list[dict] = []) -> tuple[str, list]:
    """
    Answer a question using RAG and return the answer and the retrieved context
    """
    retriever=get_retriever(db_path=db_path)
    chunks = fetch_context(question, retriever)
    messages = make_rag_messages(question, history, chunks)
    print("Messages sent to LLM:",messages)
    response = ollama_client.chat.completions.create(model=ollama_model, messages=messages)
    # return response.choices[0].message.content, chunks
    return response.choices[0].message.content

# %%
# question="where did Prathamesh completed Btech, tell me about his btech journey?"
# answer,chunks =answer_question(question, history=[])
# print(answer)

# %%
import gradio as gr 
gr.ChatInterface(answer_question).launch(inbrowser=True)
# Out:
# d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# input chunks:, [Document(id='4669674a-d3c6-4118-824b-1903e8a136b2', metadata={'type': 'resume', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\AI_ML Resume 5 Prathamesh Uravane.md'}, page_content='Prathamesh Uravane\nWashington DC, Baltimore Area | +1 (732) 318-9234 | upratham2002@gmail.com\nlinkedin.com/in/upratham/ | https://github.com/upratham|Google Scholar Profile\nEDUCATION\nUniversity of Maryland, College Park Expected: May 2027\nMaster of Science in Applied Machine Learning ; GPA: 4.0/ 4.0 College Park, Maryland\nVishwakarma University May 2024\nB.Tech in Artificial Intelligence and Data Science ; GPA: 3.75 / 4 Pune, India\n● Featured in Times of India for Developing real time fall detection system\n● AI/ML Core Team Member, Google Developer Student Club\nTECHNICAL SKILLS\nMachine Learning: Sci-kit Learn, Keras, Tensorflow, PyTorch.HuggingFace,LLMs'), Document(id='1d2f649d-951e-4fd6-a703-1f73971d9afd', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\Resume 6 Prathamesh Uravane.md', 'type': 'resume'}, page_content='Prathamesh Uravane\nWashington DC, Baltimore Area | +1 (732) 318-9234 | upratham2002@gmail.com\nlinkedin.com/in/upratham/ | https://github.com/upratham|Google Scholar Profile\nEDUCATION\nUniversity of Maryland, College Park Anticipated Graduation: May 2027\nMaster of Science in Applied Machine Learning; GPA: 4.0/ 4.0 College Park, Maryland\nVishwakarma University May 2024\nB.Tech in Artificial Intelligence and Data Science ; GPA: 3.75 / 4 Pune, India\n● Featured in Times of India for Developing real time fall detection system\n● AI/ML Core Team Member, Google Developer Student Club\nTECHNICAL SKILLS\nMachine Learning: Sci-kit Learn, Keras, Tensorflow, PyTorch.HuggingFace,LLMs'), Document(id='ff1eaadb-e8b0-4a93-be41-47a83a6f9856', metadata={'type': 'academic achievements', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\academic achievements\\ml-study-jams-gdsc-vu-2023.md'}, page_content='# Certificate of Appreciation — “ML Study Jams”\n\n## Recipient\n**Prathamesh Uravane**\n\n## Overview\nThis certificate recognizes **Prathamesh Uravane** for successfully conducting a session on **“ML STUDY JAMS”**, hosted by the **Google Developer Student Club (GDSC), Vishwakarma University**.\n\n## Key details\n- **Event/Session:** ML Study Jams  \n- **Host:** Google Developer Student Club, Vishwakarma University  \n- **Date of session:** 15 April 2023  \n- **Date of issue:** 15/04/2023  \n- **Signed by:** Preet Nahar (GDSC Lead)\n\n## Notes\nThe certificate features the **Google Developer Student Clubs** branding for **Vishwakarma University**.'), Document(id='130ddf52-d0d0-490b-a32d-7b1758766176', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\upratham.md', 'type': 'repo_summaries'}, page_content='<!-- Generated: 2026-02-15T02:59:53.128533Z | Model: gpt-4.1-nano -->\n\n# upratham Repository Documentation\n\n## Overview\nThe `upratham` repository appears to be a personal or project portfolio of Prathamesh Uravane, an applied machine learning engineer with interests spanning healthcare AI, computer vision, large language models (LLMs), MLOps, and data science. The repository likely contains code, projects, and resources related to these domains, serving as a showcase of skills, research, and applied projects.\n\n*Note:* The provided data does not specify a detailed project or codebase structure. The overview is inferred from the README content and repository metadata.'), Document(id='8cde0f34-a220-49f7-b636-fac48250fad1', metadata={'type': 'resume', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\5 Resume- Uravane Prathamesh Suhas.md'}, page_content='Uravane Prathamesh Suhas\nMalewadi-Akluj,Dist-Solapur,Maharashtra,India,413101\nIndia | (+91)9766390063| upratham200 ...
# parsed response from reranker: order=[5, 9, 10, 11, 12, 13, 1, 2, 3, 4, 14, 15, 7, 8, 6]
# reranked order of chunk ids: [5, 9, 10, 11, 12, 13, 1, 2, 3, 4, 14, 15, 7, 8, 6]
# Messages sent to LLM: [{'role': 'system', 'content': '\nYou are a helpful, knowledgeable assistant with access to a user\'s personal knowledge base.\nYour role is to answer questions about the user\'s background, experience, achievements, and projects based on provided context.\n\nwhile answering questions:\n- Dont refere any document.\n- understand the nuance of the question and depend on that provide short or long detailed answer.\n- Maintain a polite and friendly tone\n- If information is not available in the provided context, clearly state that you don\'t have that information\n- don\'t mention name of any document use it for your context only.\n- While answering strictly do not mentionany reference also , like "as per document 1, document 2, according to knowledge base" etc.\n\nContext:\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\5 Resume- Uravane Prathamesh Suhas.md:\nUravane Prathamesh Suhas\nMalewadi-Akluj,Dist-Solapur,Maharashtra,India,413101\nIndia | (+91)9766390063| upratham2002@gmail.com| https://www.linkedin.com/in/upratham/ | port folio\nEducation:\nQualification Institute University/Board Year of Passing Percentage/Grade\nBachelor of Technology Department of Science Vishwakarma University, 8.78/10\nin Artificial Intelligence and Technology Pune. 2024\nand Data Science\nHigher Secondary School VSMP Jr Maharashtra State Board\nCertificate college, of Secondary & Higher 2020 71.85\n(Class XII) Jadhav-wadi Secondary Education\nSecondary School Sadashivrao Maharashtra State Board\nCertificate Mane of Secondary & Higher 2018 97.20%\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\LLM-Debate-Competition.md:\n---\n\n## Author\nMaintained by **Prathamesh Uravane**  \nEmail: [upratham2002@gmail.com](mailto:upratham2002@gmail.com)\n\n---\n\n*Note: Some details, such as the exact implementation of the debate flow or scoring schema, are inferred from the provided files and descriptions. For precise behavior, review the `Debate_Competittion.ipynb` directly.*\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Extra cariculam\\vishwayaan-2023-chess-runner-up.md:\n# Vishwayaan 2023 – Certificate of Appreciation (Chess – Runner Up)\n\n## Overview\nA **Certificate of Appreciation** issued for participation in *Vishwayaan 2023*, acknowledging performance in the chess event.\n\n## Recipient\n- **Name:** Prathamesh Uravane\n\n## Recognition\n- **Event:** Chess  \n- **Result:** Runner Up\n\n## Issued by\n- **Vishwakarma University (VU)** / Student Council  \n- **Signed by:** Prof. Vaibhav Thakare (Director, Student Welfare)\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\academic achievements\\mtse-2018-std-10-special-prize.md:\n# Maharashtra Talent Search Examination (MTSE) — Special Prize (2018)\n\n## Awardee\n**Mr. Uravane Prathamesh Suhas**  \nSchool: **Sadashivrao Mane Vidyalaya**, Akluj (Dist. Solapur)\n\n## Overview\nCertificate from **Modern Education Society’s Centre for Talent Search & Excellence (CTSE)** recognizing **meritorious performance** in the **Maharashtra Talent Search Examination (MTSE)** for **Std. X**, conducted at the **state level** on **28 April 2018**.\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\academic achievements\\mtse-2017-std-9-taluka-prize.md:\n# Maharashtra Talent Search Examination (MTSE) — Taluka Prize (2017)\n\n## Awardee\n**Mr. Uravane Prathamesh Suhas**  \nSchool: **Sadashivrao Mane Vidyalaya**, Akluj (Dist. Solapur)\n\n## Overview\nCertificate from **Modern Education Society’s Centre for Talent Search & Excellence (CTSE)** recognizing **meritorious performance** in the **Maharashtra Talent Search Examination (MTSE)** for **Std. IX**, conducted at the **state level** on **22 April 2017**.\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge- ...
# input chunks:, [Document(id='d97d60f1-a858-4eda-9bfa-b0fc83799bb8', metadata={'type': 'resume', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\5 Resume- Uravane Prathamesh Suhas.md'}, page_content='▪ Research paper Presentation- C3I22 IEE conference - 2022\n▪ ‘Machine Learning Study Jams’ host (spoke Person)- Google Developers Student Club-2023\n▪ Maharashtra Talent Search Examination (MTSE) - Special Prize – 2018\n▪ Maharashtra Olympiad - District Topper – 2016\n▪ International Mathematics Olympiad – Class topper Rank 1 twice in 2014 and 2015\n▪ National Science Olympiad - Class topper Rank 1 – 2014\nExtra-Curricula’s:\n▪ Chess Player – Silver medal – Vishwakarma University Chess Tournament- 2023\n▪ Poetry – 1st position - Aarambha 2021 (University’s Cultural Festival) – 2021\n▪ Fashion – 2nd position - Aarambha 2021 (University’s Cultural Festival) – 2021'), Document(id='6b1cbbf8-2fa5-4492-9ef0-95ca768bd4c4', metadata={'type': 'resume', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\5 Resume- Uravane Prathamesh Suhas.md'}, page_content='▪ Poetry – 1st position - Aarambha 2021 (University’s Cultural Festival) – 2021\n▪ Fashion – 2nd position - Aarambha 2021 (University’s Cultural Festival) – 2021\n▪ Oratory – 20 + Prizes and Youth Parliament Championship - Second level Participation – 2017\n▪ Drawing - Drawing Grade exam – B grade - 2017\n▪ Yoga – Gold certificate Yogathon- 2014'), Document(id='16b10f48-e806-4bfc-9c60-cd1a6a74fc34', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Extra cariculam\\sports-championship-basketball-2016.md', 'type': 'extra cariculam'}, page_content='# Sports Championship – Certificate of Honour (Basketball)\n\n## Overview\nA **Certificate of Honour** from *Shikshan Prasarak Mandal’s Sports Championship* recognizing excellent performance in basketball.\n\n## Recipient\n- **Name:** Prathmesh Suhas Uravane\n\n## Achievement\n- **Sport:** Basketball (Category noted as “II” on the certificate)\n- **Level:** Secondary level  \n- Awarded “to honour his excellent achievement in the field of basketball”.\n\n## Event details\n- **Place:** Akluj  \n- **Date:** 27-01-2016\n\n## Authorized by\n- **Jaysinh S. Mohite-Patil**, President'), Document(id='107e96d9-494d-43a9-8393-a69ebe8330ce', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Transcripts\\hsc-12th-marksheet-maharashtra-board-2020.md', 'type': 'transcripts'}, page_content='# Higher Secondary Certificate (HSC) — Statement of Marks (February 2020)\n\n## Document type\nHigher Secondary Certificate (HSC) Examination — Statement of Marks (12th Mark Sheet), Maharashtra State Board of Secondary and Higher Secondary Education, Pune.\n\n## Candidate details\n- **Stream:** Science  \n- **Name:** Uravane Prathamesh Suhas  \n- **Mother’s name:** Bhagyashree  \n- **Seat No.:** P087163  \n- **Centre No.:** 0460  \n- **Dist. & Hr. Sec. School No.:** 24.05.023  \n- **Month & Year of Exam:** **February 2020**  \n- **Sr. No. of Statement:** 217801'), Document(id='ff8c109c-a856-4480-b254-cafda07826c1', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\academic achievements\\sof-nso-2014-participation.md', 'type': 'academic achievements'}, page_content='## Visual elements\nIncludes an NSO medal graphic labeled **“Class Topper Rank 1”** and a handwritten “Gold” note near the top.'), Document(id='0fc2e09b-86cb-4036-b836-8d98a89e6d56', metadata={'type': 'repo_summaries', 'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\UMA-V-2.md'}, page_content='---'), Document(id='6361cd5e-d287-4787-832c-087b48c0b93e', metadata={'source': 'd:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\academic achievements\\mkl-mom-2015-16-district-topper.md', 'type': 'acad ...
# parsed response from reranker: order=[1, 2, 3, 8, 12, 14, 10, 16, 5, 7, 6, 9, 4, 13, 15, 11, 9]
# reranked order of chunk ids: [1, 2, 3, 8, 12, 14, 10, 16, 5, 7, 6, 9, 4, 13, 15, 11, 9]
# Messages sent to LLM: [{'role': 'system', 'content': '\nYou are a helpful, knowledgeable assistant with access to a user\'s personal knowledge base.\nYour role is to answer questions about the user\'s background, experience, achievements, and projects based on provided context.\n\nwhile answering questions:\n- Dont refere any document.\n- understand the nuance of the question and depend on that provide short or long detailed answer.\n- Maintain a polite and friendly tone\n- If information is not available in the provided context, clearly state that you don\'t have that information\n- don\'t mention name of any document use it for your context only.\n- While answering strictly do not mentionany reference also , like "as per document 1, document 2, according to knowledge base" etc.\n\nContext:\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\5 Resume- Uravane Prathamesh Suhas.md:\n▪ Research paper Presentation- C3I22 IEE conference - 2022\n▪ ‘Machine Learning Study Jams’ host (spoke Person)- Google Developers Student Club-2023\n▪ Maharashtra Talent Search Examination (MTSE) - Special Prize – 2018\n▪ Maharashtra Olympiad - District Topper – 2016\n▪ International Mathematics Olympiad – Class topper Rank 1 twice in 2014 and 2015\n▪ National Science Olympiad - Class topper Rank 1 – 2014\nExtra-Curricula’s:\n▪ Chess Player – Silver medal – Vishwakarma University Chess Tournament- 2023\n▪ Poetry – 1st position - Aarambha 2021 (University’s Cultural Festival) – 2021\n▪ Fashion – 2nd position - Aarambha 2021 (University’s Cultural Festival) – 2021\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Resume\\5 Resume- Uravane Prathamesh Suhas.md:\n▪ Poetry – 1st position - Aarambha 2021 (University’s Cultural Festival) – 2021\n▪ Fashion – 2nd position - Aarambha 2021 (University’s Cultural Festival) – 2021\n▪ Oratory – 20 + Prizes and Youth Parliament Championship - Second level Participation – 2017\n▪ Drawing - Drawing Grade exam – B grade - 2017\n▪ Yoga – Gold certificate Yogathon- 2014\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Extra cariculam\\sports-championship-basketball-2016.md:\n# Sports Championship – Certificate of Honour (Basketball)\n\n## Overview\nA **Certificate of Honour** from *Shikshan Prasarak Mandal’s Sports Championship* recognizing excellent performance in basketball.\n\n## Recipient\n- **Name:** Prathmesh Suhas Uravane\n\n## Achievement\n- **Sport:** Basketball (Category noted as “II” on the certificate)\n- **Level:** Secondary level  \n- Awarded “to honour his excellent achievement in the field of basketball”.\n\n## Event details\n- **Place:** Akluj  \n- **Date:** 27-01-2016\n\n## Authorized by\n- **Jaysinh S. Mohite-Patil**, President\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/pdf_markdown\\Transcripts\\ssc-10th-certificate-maharashtra-board-2018.md:\n# Secondary School Certificate (SSC) — Maharashtra State Board (March 2018)\n\n## Document type\nSecondary School Certificate (SSC) / 10th Certificate — Maharashtra State Board of Secondary and Higher Secondary Education, Pune.\n\n## Candidate details\n- **Name:** Uravane Prathamesh Suhas  \n- **Mother’s name:** Bhagyashree  \n- **Division:** Pune  \n- **Seat No.:** C252384  \n- **Centre No.:** 3102  \n- **School No.:** 24.05.001  \n- **Certificate Sr. No.:** 209530  \n\n## Examination outcome\n- **Exam:** Secondary School Certificate Examination — **March 2018**\n- **Result/Grade:** **Distinction**\n- **Total:** **486 / 500**  \n- **Percentage:** **97.20%**\n\nExtract from d:\\LLM\\Projects\\LLM-RAG-private-knowldge-worker/data/processed/repo_summaries\\prathamesh-portfolio-static.md:\n- **About Section:** Skills overview with categorized badges and professional summary.\n- **Projects Showcase:** Featured projects with images, tags, impact, and tech stack.\n- **Experience Timeline ...
# Traceback (most recent call last):
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\blocks.py", line 2191, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\blocks.py", line 1696, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\utils.py", line 882, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\chat_interface.py", line 553, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\gradio\chat_interface.py", line 943, in _submit_fn
#     response = await anyio.to_thread.run_sync(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\anyio\to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\upratham\AppData\Local\Temp\ipykernel_8164\3971853878.py", line 12, in answer_question
#     response = ollama_client.chat.completions.create(model=ollama_model, messages=messages)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\openai\_utils\_utils.py", line 286, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 1192, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\openai\_base_client.py", line 1297, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\LLM\Projects\LLM-RAG-private-knowldge-worker\.venv\Lib\site-packages\openai\_base_client.py", line 1070, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.BadRequestError: Error code: 400 - {'error': {'message': 'json: cannot unmarshal array into Go struct field ChatCompletionRequest.messages of type openai.Message', 'type': 'invalid_request_error', 'param': None, 'code': None}}
